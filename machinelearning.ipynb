# %% [markdown]
# <a href="https://colab.research.google.com/github/syildirim0/machine_learning/blob/main/machinelearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv('https://raw.githubusercontent.com/HakkiKaanSimsek/Makine_Ogrenmesi_Dersleri/master/3.karar_agaclari/ml_3b_siniflandirma/data/adult.csv')
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       32561 non-null  int64
#  1   1       32561 non-null  object
#  2   2       32561 non-null  int64
#  3   3       32561 non-null  object
#  4   4       32561 non-null  int64
#  5   5       32561 non-null  object
#  6   6       32561 non-null  object
#  7   7       32561 non-null  object
#  8   8       32561 non-null  object
#  9   9       32561 non-null  object
#  10  10      32561 non-null  int64
#  11  11      32561 non-null  int64
#  12  12      32561 non-null  int64
#  13  13      32561 non-null  object
#  14  14      32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB
#     0                  1       2           3  ...  11  12              13      14
# 0  39          State-gov   77516   Bachelors  ...   0  40   United-States   <=50K
# 1  50   Self-emp-not-inc   83311   Bachelors  ...   0  13   United-States   <=50K
# 2  38            Private  215646     HS-grad  ...   0  40   United-States   <=50K
# 3  53            Private  234721        11th  ...   0  40   United-States   <=50K
# 4  28            Private  338409   Bachelors  ...   0  40            Cuba   <=50K
#
# [5 rows x 15 columns]

# %%
df.columns=['age', 'workclass', 'fnlwgt', 'education', 'education-num', 'marital-status', 'occupation', 
              'relationship','race', 'sex', 'capital-gain', 'capital-loss', 'hours-per-week', 
              'native-country', 'salary']

# %%
X = df.drop(['salary'], axis=1)
y = df['salary']
print('Salary Distribution:')
print(y.value_counts())
y = np.where(df['salary'] == ' <=50K',0,1)
# Out:
# Salary Distribution:
#  <=50K    24720
#  >50K      7841
# Name: salary, dtype: int64

# %%
df['capital-gain'] = df['capital-gain'].astype(float)
X.select_dtypes(include='object').tail(20)
# Out:
#                workclass      education  ...      sex  native-country
# 32541                  ?        HS-grad  ...   Female   United-States
# 32542                  ?        HS-grad  ...     Male   United-States
# 32543          Local-gov     Assoc-acdm  ...   Female   United-States
# 32544            Private        Masters  ...   Female   United-States
# 32545          Local-gov     Assoc-acdm  ...   Female   United-States
# 32546            Private     Assoc-acdm  ...   Female   United-States
# 32547            Private        HS-grad  ...     Male          Mexico
# 32548   Self-emp-not-inc    Prof-school  ...     Male   United-States
# 32549          State-gov   Some-college  ...   Female   United-States
# 32550   Self-emp-not-inc   Some-college  ...     Male   United-States
# 32551            Private           10th  ...     Male   United-States
# 32552            Private      Assoc-voc  ...     Male   United-States
# 32553            Private        Masters  ...     Male          Taiwan
# 32554            Private        Masters  ...     Male   United-States
# 32555            Private   Some-college  ...     Male   United-States
# 32556            Private     Assoc-acdm  ...   Female   United-States
# 32557            Private        HS-grad  ...     Male   United-States
# 32558            Private        HS-grad  ...   Female   United-States
# 32559            Private        HS-grad  ...     Male   United-States
# 32560       Self-emp-inc        HS-grad  ...   Female   United-States
#
# [20 rows x 8 columns]

# %%
categorical_columns= [c for c in X.columns if X[c].dtype.name == 'object']
for c in categorical_columns:
  X[c] = np.where(X[c] == ' ?', X[c].mode(), df[c])
X.select_dtypes(include='object').tail(20)
# Out:
#                workclass      education  ...      sex  native-country
# 32541            Private        HS-grad  ...   Female   United-States
# 32542            Private        HS-grad  ...     Male   United-States
# 32543          Local-gov     Assoc-acdm  ...   Female   United-States
# 32544            Private        Masters  ...   Female   United-States
# 32545          Local-gov     Assoc-acdm  ...   Female   United-States
# 32546            Private     Assoc-acdm  ...   Female   United-States
# 32547            Private        HS-grad  ...     Male          Mexico
# 32548   Self-emp-not-inc    Prof-school  ...     Male   United-States
# 32549          State-gov   Some-college  ...   Female   United-States
# 32550   Self-emp-not-inc   Some-college  ...     Male   United-States
# 32551            Private           10th  ...     Male   United-States
# 32552            Private      Assoc-voc  ...     Male   United-States
# 32553            Private        Masters  ...     Male          Taiwan
# 32554            Private        Masters  ...     Male   United-States
# 32555            Private   Some-college  ...     Male   United-States
# 32556            Private     Assoc-acdm  ...   Female   United-States
# 32557            Private        HS-grad  ...     Male   United-States
# 32558            Private        HS-grad  ...   Female   United-States
# 32559            Private        HS-grad  ...     Male   United-States
# 32560       Self-emp-inc        HS-grad  ...   Female   United-States
#
# [20 rows x 8 columns]

# %%
X = pd.concat([X, pd.get_dummies(X.select_dtypes(include='object'))], axis=1)
X = X.drop(['workclass', 'education', 'marital-status', 'occupation',
       'relationship', 'race', 'sex', 'native-country'], axis=1)
X.head()
# Out:
#    age  fnlwgt  ...  native-country_ Vietnam  native-country_ Yugoslavia
# 0   39   77516  ...                        0                           0
# 1   50   83311  ...                        0                           0
# 2   38  215646  ...                        0                           0
# 3   53  234721  ...                        0                           0
# 4   28  338409  ...                        0                           0
#
# [5 rows x 105 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix as cm
X_train,X_test,y_train,y_test= train_test_split(X,y, test_size=0.3, random_state=42)
tree1= DecisionTreeClassifier(max_depth= 2, random_state=42)
tree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=2, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=42, splitter='best')

# %%
predictions= tree1.predict(X_test)
score= round(accuracy_score(y_test,predictions),3)
cm = cm(y_test,predictions)
sns.heatmap(cm, annot=True, fmt=' .0f')
plt.xlabel('Predicted Values')
plt.ylabel('Actual Values')
plt.title('Accuracy_score:{}' .format(score), size=15)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions, target_names=[' <=50K', '>50K']))
# Out:
#               precision    recall  f1-score   support
#
#        <=50K       0.84      0.95      0.89      7455
#         >50K       0.73      0.44      0.55      2314
#
#     accuracy                           0.83      9769
#    macro avg       0.79      0.69      0.72      9769
# weighted avg       0.82      0.83      0.81      9769

# %%
from sklearn.tree import export_graphviz
from sklearn import tree
from IPython.display import SVG
from graphviz import Source
from IPython.display import display

# %%
graph = Source(tree.export_graphviz(tree1, out_file=None,feature_names=X.columns, 
                                    filled = True))
display(SVG(graph.pipe(format='svg')))

# %%
plt.figure(figsize= (16,9))
from sklearn import ensemble
tree2=DecisionTreeClassifier(max_depth= 8, random_state=42)
tree2.fit(X_train,y_train)
ranking=tree2.feature_importances_
features=np.argsort(ranking)[::-1][:10]
columns=X.columns

plt.title("Feature importances based on Decision Tree Classifier", y = 1.03, size = 18)
plt.bar(range(len(features)), ranking[features], color="lime", align="center")
plt.xticks(range(len(features)), columns[features], rotation=80)
plt.show()

# %% [markdown]
# # New section
